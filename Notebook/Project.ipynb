# %% [markdown]
# # <h1><center>Us Census Demographic Data Analysis</center></h1>

# %% [markdown]
# # Link
# ### https://public.tableau.com/app/profile/ahmed.khalid/viz/Book5_16410707530390/Dashboard1?publish=yes

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)
